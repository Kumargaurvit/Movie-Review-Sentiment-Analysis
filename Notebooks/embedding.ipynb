# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# c:\Users\gaurv\Downloads\STUDY\Deep Learning\Implementations\RNN\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
sent=[
'the glass of milk',
'the glass of juice',
'the cup of tea',
'I am a good boy',
'I am a good developer',
'understand the meaning of words',
'your videos are good',
]

# %%
vocab_size = 10000

# %%
# One Hot Representation
one_hot_repr = [one_hot(words,vocab_size) for words in sent]
one_hot_repr
# Out:
# [[5946, 9839, 4482, 3300],
#  [5946, 9839, 4482, 21],
#  [5946, 4464, 4482, 5592],
#  [6391, 9615, 5861, 9512, 6051],
#  [6391, 9615, 5861, 9512, 3755],
#  [5921, 5946, 8648, 4482, 472],
#  [7564, 3938, 4838, 9512]]

# %%
# Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8

# %%
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 5946 9839 4482 3300]
#  [   0    0    0    0 5946 9839 4482   21]
#  [   0    0    0    0 5946 4464 4482 5592]
#  [   0    0    0 6391 9615 5861 9512 6051]
#  [   0    0    0 6391 9615 5861 9512 3755]
#  [   0    0    0 5921 5946 8648 4482  472]
#  [   0    0    0    0 7564 3938 4838 9512]]

# %%
# Feature Representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(vocab_size,dim,input_shape=(sent_length,)))
model.compile('adam','mse')
# Out:
# c:\Users\gaurv\Downloads\STUDY\Deep Learning\Implementations\RNN\venv\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# array([[[-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.02938356,  0.00076536, -0.0478016 , -0.00465096,
#          -0.0238128 , -0.01619065, -0.00320375, -0.02756645,
#          -0.04030541,  0.01661747],
#         [-0.04697257,  0.02095095,  0.0179552 ,  0.02523751,
#           0.03083552, -0.03749432, -0.03007975,  0.01442292,
#           0.02878774, -0.02245398],
#         [ 0.02002852, -0.00028477,  0.01475604, -0.03366327,
#          -0.02300185,  0.03766007,  0.03378591, -0.04314772,
#          -0.02709713, -0.0378493 ],
#         [-0.03867915, -0.03516456,  0.01955644,  0.0114123 ,
#           0.02650416, -0.02193379, -0.0484225 , -0.03042802,
#           0.04149643,  0.01529188]],
#
#        [[-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#         [ 0.00050785,  0.0154336 ,  0.02703248,  0.00971748,
#          -0.03562875, -0.03160219, -0.03285841, -0.02145679,
#           0.03351818, -0.03511052],
#         [-0.03426071, -0.00960959, -0.00011226,  0.03795064,
#          -0.04482485,  0.04059962, -0.03548452,  0.04143352,
#           0.04591206, -0.02553574],
#         [ 0.02997681,  0.01594486, -0.0233951 , -0.00225164,
#          -0.02556669, -0.01621513,  0.04506585,  0.00119245,
#          -0.00433993, -0.00870131],
#         [ 0.01079195, -0.03062186,  0.04220882,  0.02435878,
#          -0.01072912,  0.01171273,  0.04272166, -0.02590145,
#           0.01343476,  0.00492246],
#         [-0.02161839,  0.02886522, -0.02789292,  0.04641911,
#           0.02183664, -0.03423236,  0.02769906, -0.03635548,
#           0.03139845, -0.04539476]],
#
#        [[-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [ 0.00050785,  0.0154336 ,  0.02703248,  0.00971748,
#          -0.03562875, -0.03160219, -0.03285841, -0.02145679,
#           0.03351818, -0.03511052],
#         [-0.03426071, -0.00960959, -0.00011226,  0.03795064,
#          -0.04482485,  0.04059962, -0.03548452,  0.04143352,
#           0.04591206, -0.02553574],
#         [ 0.02997681,  0.01594486, -0.0233951 , -0.00225164,
#          -0.02556669, -0.01621513,  0.04506585,  0.00119245,
#          -0.00433993, -0.00870131],
#         [ 0.01079195, -0.03062186,  0.04220882,  0.02435878,
#          -0.01072912,  0.01171273,  0.04272166, -0.02590145,
#           0.01343476,  0.00492246],
#         [-0.01647679,  0.01588576, -0.04866911,  0.02556232,
#           0.00684066, -0.0200995 , -0.00521691, -0.01626023,
#           0.0165876 , -0.01495423]],
#
#        [[-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.0482005 , -0.04116906,  0.00711495,  0.01710201,
#           0.01505537, -0.04843732, -0.00612271, -0.01047436,
#          -0.00958159,  0.01040859],
#         [-0.02938356,  0.00076536, -0.0478016 , -0.00465096,
#          -0.0238128 , -0.01619065, -0.00320375, -0.02756645,
#          -0.04030541,  0.01661747],
#         [-0.02858208,  0.02637259,  0.02103225, -0.03366196,
#           0.04667469, -0.03966017, -0.04529526, -0.04638544,
#           0.03768275, -0.03070113],
#         [ 0.02002852, -0.00028477,  0.01475604, -0.03366327,
#          -0.02300185,  0.03766007,  0.03378591, -0.04314772,
#          -0.02709713, -0.0378493 ],
#         [-0.04828918,  0.0322733 ,  0.00767093,  0.01850018,
#           0.04684914,  0.03163798, -0.01182304,  0.03787965,
#          -0.01609764,  0.04828865]],
#
#        [[-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,
#           0.01965506, -0.0248996 ,  0.02727529,  0.02531173,
#          -0.03976103, -0.04287262],
#         [-0.00158126,  0.04442492,  0.04495842,  0.04427166,
#           0.03492694, -0.0299395 , -0.01101899, -0.02251892,
#           0.03844477, -0.02365513],
#         [-0.04783049,  0.03882605,  0.0160699 , -0.04253818,
#          -0.02820228, -0.02034067, -0.01551553,  0.01690922,
#          -0.00225616,  0.02754407],
#         [-0.02698605,  0.04204197,  0.00982635, -0.00039857,
#           0.00534983, -0.03932651,  0.0197703 , -0.02554764,
#           0.03524227, -0.03307599],
#         [ 0.01079195, -0.03062186,  0.04220882,  0.02435878,
#          -0.01072912,  0.01171273,  0.04272166, -0.02590145,
#           0.01343476,  0.00492246]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 5946, 9839, 4482, 3300], dtype=int32)

# %%
model.predict(embedded_docs)[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# array([[-0.04403061, -0.0434509 , -0.03606122, -0.02744368,  0.01965506,
#         -0.0248996 ,  0.02727529,  0.02531173, -0.03976103, -0.04287262],
#        [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,  0.01965506,
#         -0.0248996 ,  0.02727529,  0.02531173, -0.03976103, -0.04287262],
#        [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,  0.01965506,
#         -0.0248996 ,  0.02727529,  0.02531173, -0.03976103, -0.04287262],
#        [-0.04403061, -0.0434509 , -0.03606122, -0.02744368,  0.01965506,
#         -0.0248996 ,  0.02727529,  0.02531173, -0.03976103, -0.04287262],
#        [-0.02938356,  0.00076536, -0.0478016 , -0.00465096, -0.0238128 ,
#         -0.01619065, -0.00320375, -0.02756645, -0.04030541,  0.01661747],
#        [-0.04697257,  0.02095095,  0.0179552 ,  0.02523751,  0.03083552,
#         -0.03749432, -0.03007975,  0.01442292,  0.02878774, -0.02245398],
#        [ 0.02002852, -0.00028477,  0.01475604, -0.03366327, -0.02300185,
#          0.03766007,  0.03378591, -0.04314772, -0.02709713, -0.0378493 ],
#        [-0.03867915, -0.03516456,  0.01955644,  0.0114123 ,  0.02650416,
#         -0.02193379, -0.0484225 , -0.03042802,  0.04149643,  0.01529188]],
#       dtype=float32)
